# %% [markdown]
# # Cross Validation for Tuned Neural Network Model

# %% [markdown]
# ### 0. Read Data from Prev Notebook

# %%
import pandas as pd

df = pd.read_csv('data-stage2.csv')
df
# Out:
#                category     amt  is_fraud  hour  trans_count_7d  \
# 0              misc_net    4.97         0     1             0.0
# 1           grocery_pos  107.23         0     1             0.0
# 2         entertainment  220.11         0     1             0.0
# 3         gas_transport   45.00         0     1             0.0
# 4              misc_pos   41.96         0     1             0.0
# ...                 ...     ...       ...   ...             ...
# 1852389  health_fitness   43.77         0     1            39.0
# 1852390       kids_pets  111.84         0     1            62.0
# 1852391       kids_pets   86.88         0     1            67.0
# 1852392          travel    7.99         0     1            36.0
# 1852393   entertainment   38.13         0     1            67.0
#
#          trans_count_30d  time_diff
# 0                    0.0   0.000000
# 1                    0.0   0.000000
# 2                    0.0   0.000000
# 3                    0.0   0.000000
# 4                    0.0   0.000000
# ...                  ...        ...
# 1852389            167.0   4.619444
# 1852390            272.0   2.706389
# 1852391            277.0   0.201111
# 1852392            192.0   3.340278
# 1852393            286.0   1.982222
#
# [1852394 rows x 7 columns]

# %% [markdown]
# ### 1. Scaling and Encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn import set_config

preprocessor = ColumnTransformer(
    transformers=[
        ("num", MinMaxScaler(), make_column_selector(dtype_include="float64")),
        ("cat", OneHotEncoder(), make_column_selector(dtype_include="object")),
    ],
    remainder='passthrough'
)

set_config(display="diagram")

preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num', MinMaxScaler(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f8bf5c3c550>),
#                                 ('cat', OneHotEncoder(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f8bf5c3c518>)])

# %%
X = preprocessor.fit_transform(df.drop(columns=['is_fraud']))
y = df[['is_fraud']]

# %% [markdown]
# ### 2. Create Neural Network Model with the Best Set of Hyper-parameters
#
# Please refer to `hyperparameter_tuning_v2.ipynb` for how we get the hyper-parameters by using Keras Tuner.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.models.Sequential([keras.Input(shape=(19),)])

layer1_num_units = np.ceil(.9*19)
layer2_num_units = np.ceil(.8*layer1_num_units)
layer3_num_units = np.ceil(.6*layer2_num_units)
layer4_num_units = np.ceil(.7*layer3_num_units)

# Create hidden layers
model.add(
    layers.Dense(
        units=layer1_num_units,
        activation="relu",
    )
)

model.add(
   layers.Dense(
        units=layer2_num_units,
        activation="relu",
    )
)

model.add(
   layers.Dense(
        units=layer3_num_units,
        activation="relu",
    )
)

model.add(
   layers.Dense(
        units=layer4_num_units,
        activation="relu",
    )
)

# Single output layer
model.add(
    layers.Dense(
        units=1, 
        activation="sigmoid"
    )
)

# Compile model, tune learning rate
model.compile(
    optimizer=keras.optimizers.SGD(1e-2),
    loss=keras.losses.BinaryCrossentropy(), 
    metrics=[
        keras.metrics.BinaryAccuracy(name="accuracy"),
        keras.metrics.Precision(name="precision"),
        keras.metrics.Recall(name="recall")
    ]
)

# %% [markdown]
# ## 3. 5-fold Cross Validation

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE

# oversampling (using training set)
smote = SMOTE(n_jobs=-1)
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.24 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: numpy>=1.13.3 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.8.1 imblearn-0.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/bin/python -m pip install --upgrade pip' command.

# %%
# k-fold Cross Validation

from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle = True)

i = 0
for train_i, test_i in kf.split(X):
    start_train, stop_train = train_i[0], train_i[-1]+1
    start_test, stop_test = test_i[0], test_i[-1]+1
    
    x_train, y_train = X[start_train:stop_train], y[start_train:stop_train],
    x_test, y_test = X[start_test:stop_test], y[start_test:stop_test]
    x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)
    
    history = model.fit(
        x_train_smote,
        y_train_smote,
        epochs=10,  # best param is 50, but took too long
        validation_data=(x_test, y_test),
        workers=16,
        use_multiprocessing=True
    )
    i += 1
    print("\n=====", i, "=====")
    print("Evaluate on test data")
    results = model.evaluate(x_test, y_test)
    print("loss, accuracy, precision, recall:", results, "\n\n")
# Out:
# Epoch 1/10
# 115172/115172 [==============================] - 135s 1ms/step - loss: 0.0954 - accuracy: 0.9602 - precision: 0.9646 - recall: 0.9555 - val_loss: 0.0971 - val_accuracy: 0.9630 - val_precision: 0.1179 - val_recall: 0.9425
# Epoch 2/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0952 - accuracy: 0.9604 - precision: 0.9647 - recall: 0.9558 - val_loss: 0.0971 - val_accuracy: 0.9642 - val_precision: 0.1219 - val_recall: 0.9455
# Epoch 3/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0953 - accuracy: 0.9603 - precision: 0.9646 - recall: 0.9556 - val_loss: 0.0933 - val_accuracy: 0.9662 - val_precision: 0.1290 - val_recall: 0.9533
# Epoch 4/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0950 - accuracy: 0.9604 - precision: 0.9646 - recall: 0.9558 - val_loss: 0.1091 - val_accuracy: 0.9566 - val_precision: 0.1042 - val_recall: 0.9635
# Epoch 5/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0950 - accuracy: 0.9604 - precision: 0.9646 - recall: 0.9559 - val_loss: 0.0720 - val_accuracy: 0.9744 - val_precision: 0.1624 - val_recall: 0.9410
# Epoch 6/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0948 - accuracy: 0.9605 - precision: 0.9647 - recall: 0.9560 - val_loss: 0.0923 - val_accuracy: 0.9661 - val_precision: 0.1284 - val_recall: 0.9518
# Epoch 7/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0948 - accuracy: 0.9606 - precision: 0.9647 - recall: 0.9561 - val_loss: 0.0806 - val_accuracy: 0.9701 - val_precision: 0.1426 - val_recall: 0.9472
# Epoch 8/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0946 - accuracy: 0.9605 - precision: 0.9646 - recall: 0.9562 - val_loss: 0.1040 - val_accuracy: 0.9600 - val_precision: 0.1113 - val_recall: 0.9574
# Epoch 9/10
# 115172/115172 [==============================] - 135s 1ms/step - loss: 0.0946 - accuracy: 0.9605 - precision: 0.9647 - recall: 0.9561 - val_loss: 0.1055 - val_accuracy: 0.9594 - val_precision: 0.1093 - val_recall: 0.9496
# Epoch 10/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0943 - accuracy: 0.9607 - precision: 0.9648 - recall: 0.9564 - val_loss: 0.0994 - val_accuracy: 0.9623 - val_precision: 0.1176 - val_recall: 0.9579
#
# ===== 1 =====
# Evaluate on test data
# 57887/57887 [==============================] - 48s 824us/step - loss: 0.0994 - accuracy: 0.9623 - precision: 0.1176 - recall: 0.9579
# loss, accuracy, precision, recall: [0.09937392175197601, 0.9623278379440308, 0.11758795380592346, 0.9579318165779114]
#
#
# Epoch 1/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0941 - accuracy: 0.9607 - precision: 0.9649 - recall: 0.9562 - val_loss: 0.1069 - val_accuracy: 0.9589 - val_precision: 0.1087 - val_recall: 0.9562
# Epoch 2/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0940 - accuracy: 0.9608 - precision: 0.9650 - recall: 0.9562 - val_loss: 0.0994 - val_accuracy: 0.9616 - val_precision: 0.1151 - val_recall: 0.9543
# Epoch 3/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0940 - accuracy: 0.9607 - precision: 0.9648 - recall: 0.9562 - val_loss: 0.1317 - val_accuracy: 0.9551 - val_precision: 0.0867 - val_recall: 0.7994
# Epoch 4/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0937 - accuracy: 0.9609 - precision: 0.9651 - recall: 0.9564 - val_loss: 0.0909 - val_accuracy: 0.9661 - val_precision: 0.1286 - val_recall: 0.9534
# Epoch 5/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0936 - accuracy: 0.9609 - precision: 0.9650 - recall: 0.9565 - val_loss: 0.4844 - val_accuracy: 0.8671 - val_precision: 0.0353 - val_recall: 0.9305
# Epoch 6/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0937 - accuracy: 0.9609 - precision: 0.9649 - recall: 0.9565 - val_loss: 0.0758 - val_accuracy: 0.9734 - val_precision: 0.1571 - val_recall: 0.9422
# Epoch 7/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0932 - accuracy: 0.9611 - precision: 0.9650 - recall: 0.9568 - val_loss: 0.0867 - val_accuracy: 0.9685 - val_precision: 0.1367 - val_recall: 0.9484
# Epoch 8/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0931 - accuracy: 0.9611 - precision: 0.9650 - recall: 0.9569 - val_loss: 0.0974 - val_accuracy: 0.9641 - val_precision: 0.1228 - val_recall: 0.9576
# Epoch 9/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0931 - accuracy: 0.9610 - precision: 0.9650 - recall: 0.9568 - val_loss: 0.0712 - val_accuracy: 0.9747 - val_precision: 0.1641 - val_recall: 0.9421
# Epoch 10/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0930 - accuracy: 0.9611 - precision: 0.9649 - recall: 0.9570 - val_loss: 0.0866 - val_accuracy: 0.9682 - val_precision: 0.1359 - val_recall: 0.9503
#
# ===== 2 =====
# Evaluate on test data
# 57888/57888 [==============================] - 48s 834us/step - loss: 0.0866 - accuracy: 0.9682 - precision: 0.1359 - recall: 0.9503
# loss, accuracy, precision, recall: [0.08657857775688171, 0.9682480096817017, 0.13585056364536285, 0.9502642154693604]
#
#
# Epoch 1/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0930 - accuracy: 0.9610 - precision: 0.9649 - recall: 0.9569 - val_loss: 0.0739 - val_accuracy: 0.9731 - val_precision: 0.1556 - val_recall: 0.9420
# Epoch 2/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0929 - accuracy: 0.9611 - precision: 0.9649 - recall: 0.9569 - val_loss: 0.0881 - val_accuracy: 0.9671 - val_precision: 0.1318 - val_recall: 0.9525
# Epoch 3/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0929 - accuracy: 0.9611 - precision: 0.9650 - recall: 0.9570 - val_loss: 0.0884 - val_accuracy: 0.9682 - val_precision: 0.1346 - val_recall: 0.9407
# Epoch 4/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0925 - accuracy: 0.9612 - precision: 0.9651 - recall: 0.9570 - val_loss: 0.0753 - val_accuracy: 0.9728 - val_precision: 0.1546 - val_recall: 0.9432
# Epoch 5/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0925 - accuracy: 0.9612 - precision: 0.9652 - recall: 0.9570 - val_loss: 0.0974 - val_accuracy: 0.9638 - val_precision: 0.1217 - val_recall: 0.9559
# Epoch 6/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0924 - accuracy: 0.9613 - precision: 0.9652 - recall: 0.9572 - val_loss: 0.1155 - val_accuracy: 0.9571 - val_precision: 0.1039 - val_recall: 0.9506
# Epoch 7/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0924 - accuracy: 0.9614 - precision: 0.9653 - recall: 0.9572 - val_loss: 0.1038 - val_accuracy: 0.9599 - val_precision: 0.1116 - val_recall: 0.9609
# Epoch 8/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0921 - accuracy: 0.9614 - precision: 0.9654 - recall: 0.9572 - val_loss: 0.0899 - val_accuracy: 0.9666 - val_precision: 0.1303 - val_recall: 0.9532
# Epoch 9/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0920 - accuracy: 0.9615 - precision: 0.9654 - recall: 0.9572 - val_loss: 0.0862 - val_accuracy: 0.9668 - val_precision: 0.1314 - val_recall: 0.9558
# Epoch 10/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0921 - accuracy: 0.9615 - precision: 0.9653 - recall: 0.9574 - val_loss: 0.1118 - val_accuracy: 0.9572 - val_precision: 0.1050 - val_recall: 0.9581
#
# ===== 3 =====
# Evaluate on test data
# 57888/57888 [==============================] - 48s 836us/step - loss: 0.1118 - accuracy: 0.9572 - precision: 0.1050 - recall: 0.9581
# loss, accuracy, precision, recall: [0.1117834597826004, 0.957212507724762, 0.10495788604021072, 0.9581390619277954]
#
#
# Epoch 1/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0919 - accuracy: 0.9617 - precision: 0.9655 - recall: 0.9576 - val_loss: 0.0864 - val_accuracy: 0.9687 - val_precision: 0.1373 - val_recall: 0.9493
# Epoch 2/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0915 - accuracy: 0.9618 - precision: 0.9656 - recall: 0.9578 - val_loss: 0.1017 - val_accuracy: 0.9608 - val_precision: 0.1134 - val_recall: 0.9572
# Epoch 3/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0916 - accuracy: 0.9618 - precision: 0.9655 - recall: 0.9579 - val_loss: 0.0841 - val_accuracy: 0.9683 - val_precision: 0.1361 - val_recall: 0.9505
# Epoch 4/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0914 - accuracy: 0.9619 - precision: 0.9655 - recall: 0.9580 - val_loss: 0.0784 - val_accuracy: 0.9722 - val_precision: 0.1517 - val_recall: 0.9442
# Epoch 5/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0912 - accuracy: 0.9620 - precision: 0.9657 - recall: 0.9581 - val_loss: 0.0895 - val_accuracy: 0.9673 - val_precision: 0.1323 - val_recall: 0.9513
# Epoch 6/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0910 - accuracy: 0.9620 - precision: 0.9656 - recall: 0.9581 - val_loss: 0.1055 - val_accuracy: 0.9600 - val_precision: 0.1108 - val_recall: 0.9504
# Epoch 7/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0910 - accuracy: 0.9620 - precision: 0.9656 - recall: 0.9581 - val_loss: 0.0925 - val_accuracy: 0.9663 - val_precision: 0.1291 - val_recall: 0.9522
# Epoch 8/10
# 115172/115172 [==============================] - 135s 1ms/step - loss: 0.0908 - accuracy: 0.9622 - precision: 0.9656 - recall: 0.9585 - val_loss: 0.0673 - val_accuracy: 0.9754 - val_precision: 0.1633 - val_recall: 0.9028
# Epoch 9/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0909 - accuracy: 0.9622 - precision: 0.9656 - recall: 0.9585 - val_loss: 0.0747 - val_accuracy: 0.9726 - val_precision: 0.1537 - val_recall: 0.9467
# Epoch 10/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0906 - accuracy: 0.9622 - precision: 0.9657 - recall: 0.9585 - val_loss: 0.0958 - val_accuracy: 0.9642 - val_precision: 0.1230 - val_recall: 0.9561
#
# ===== 4 =====
# Evaluate on test data
# 57888/57888 [==============================] - 48s 828us/step - loss: 0.0958 - accuracy: 0.9642 - precision: 0.1230 - recall: 0.9561
# loss, accuracy, precision, recall: [0.0958017110824585, 0.9642418622970581, 0.1229594498872757, 0.9560667276382446]
#
#
# Epoch 1/10
# 115172/115172 [==============================] - 132s 1ms/step - loss: 0.0907 - accuracy: 0.9621 - precision: 0.9654 - recall: 0.9586 - val_loss: 0.0862 - val_accuracy: 0.9674 - val_precision: 0.1330 - val_recall: 0.9529
# Epoch 2/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0904 - accuracy: 0.9623 - precision: 0.9656 - recall: 0.9587 - val_loss: 0.0810 - val_accuracy: 0.9704 - val_precision: 0.1440 - val_recall: 0.9478
# Epoch 3/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0904 - accuracy: 0.9622 - precision: 0.9656 - recall: 0.9587 - val_loss: 0.0770 - val_accuracy: 0.9728 - val_precision: 0.1546 - val_recall: 0.9457
# Epoch 4/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0904 - accuracy: 0.9622 - precision: 0.9654 - recall: 0.9587 - val_loss: 0.0659 - val_accuracy: 0.9770 - val_precision: 0.1773 - val_recall: 0.9382
# Epoch 5/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0903 - accuracy: 0.9623 - precision: 0.9656 - recall: 0.9587 - val_loss: 0.0757 - val_accuracy: 0.9728 - val_precision: 0.1547 - val_recall: 0.9467
# Epoch 6/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0900 - accuracy: 0.9624 - precision: 0.9657 - recall: 0.9590 - val_loss: 0.0883 - val_accuracy: 0.9677 - val_precision: 0.1342 - val_recall: 0.9537
# Epoch 7/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0901 - accuracy: 0.9624 - precision: 0.9656 - recall: 0.9589 - val_loss: 0.1254 - val_accuracy: 0.9529 - val_precision: 0.0957 - val_recall: 0.9522
# Epoch 8/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0900 - accuracy: 0.9624 - precision: 0.9657 - recall: 0.9590 - val_loss: 0.0816 - val_accuracy: 0.9700 - val_precision: 0.1424 - val_recall: 0.9467
# Epoch 9/10
# 115172/115172 [==============================] - 133s 1ms/step - loss: 0.0900 - accuracy: 0.9624 - precision: 0.9656 - recall: 0.9590 - val_loss: 0.0788 - val_accuracy: 0.9714 - val_precision: 0.1484 - val_recall: 0.9483
# Epoch 10/10
# 115172/115172 [==============================] - 134s 1ms/step - loss: 0.0897 - accuracy: 0.9626 - precision: 0.9658 - recall: 0.9591 - val_loss: 0.0807 - val_accuracy: 0.9697 - val_precision: 0.1419 - val_recall: 0.9529
#
# ===== 5 =====
# Evaluate on test data
# 57887/57887 [==============================] - 49s 839us/step - loss: 0.0807 - accuracy: 0.9697 - precision: 0.1419 - recall: 0.9529
# loss, accuracy, precision, recall: [0.08073359727859497, 0.9697291254997253, 0.14188292622566223, 0.9528546333312988]
